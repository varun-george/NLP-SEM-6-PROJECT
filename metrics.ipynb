# %%
from IPython.display import Image
import os

# %%
current = os.getcwd()
root = os.path.dirname(current)
metrics_path = os.path.join(root,'metrics')

# %%
os.listdir(metrics_path)
# Out:
# ['bow.png', 'doc2vec.png', 'ft.png', 'sbert.png', 'tf-idf.png']

# %%
img_1 = os.path.join(metrics_path,'bow.png')
img_2 = os.path.join(metrics_path,'tf-idf.png')
img_5 = os.path.join(metrics_path,'ft.png')
img_3 = os.path.join(metrics_path,'doc2vec.png')
img_4 = os.path.join(metrics_path,'sbert.png')

# %% [markdown]
# #### BAG OF WORDS

# %%
Image(filename=img_1)

# %% [markdown]
# #### TF-IDF

# %%
Image(filename=img_2)

# %% [markdown]
# #### FastText

# %%
Image(filename=img_5)

# %% [markdown]
# #### DOC2VEC

# %%
Image(filename=img_3)

# %% [markdown]
# #### SENTENCE BERT

# %%
Image(filename=img_4)
