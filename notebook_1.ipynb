# %%
# nltk.download('stopwords')
# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('omw-1.4')
# nltk.download('words')
# nltk.download('averaged_perceptron_tagger')

# %%
# pip install spacy

# %%
# pip install sentence-transformers

# %% [markdown]
# THIS NOTEBOOK CONTAINS THE DATASET EXPLORATION, PREPEOCESSING AND TYPES OF VECTORIZATION.
#
#
# WORDS-EMBEDDINGS -> TF-IDF
# SENTENCE-EMBEDDINGS -> DOC2VEC
#
# MODELS USED -> SVM, COSINE SIMILARITY

# %%
import pandas as pd
import numpy as np
import regex as re
from tqdm import tqdm
import os 
import contractions

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import classification_report

import spacy
from spacy import displacy

from sentence_transformers import SentenceTransformer
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.models import FastText

import warnings
warnings.filterwarnings('ignore')

# %%
current_dir = os.getcwd()
root = os.path.dirname(current_dir)
data_dir = os.path.join(root,'data')
data_path = os.path.join(data_dir,'msr_paraphrase_train.txt')

# %%
quality = []
ID_1 = []
ID_2 = []
STRING_1 = []
STRING_2 = []

text_lines = []

# %%
fe = open(data_path,'r',encoding='utf8')
columns = fe.readline().removeprefix('\ufeff').removesuffix('\n').split('\t')
# print(columns)
for line in fe:
    text_lines.append(line.strip().split('/n'))

# %%
for lines in text_lines:
    line = str(lines[0])
    split_lines = line.split('\t')
    quality.append(split_lines[0])
    STRING_1.append(split_lines[3])
    STRING_2.append(split_lines[4])

fe.close()

# %%
df = pd.DataFrame(np.column_stack([quality,STRING_1,STRING_2]),columns=['Quality','String-1','String-2'])

# %%
df
# Out:
#      Quality                                           String-1  \
# 0          1  Amrozi accused his brother, whom he called "th...
# 1          0  Yucaipa owned Dominick's before selling the ch...
# 2          1  They had published an advertisement on the Int...
# 3          0  Around 0335 GMT, Tab shares were up 19 cents, ...
# 4          1  The stock rose $2.11, or about 11 percent, to ...
# ...      ...                                                ...
# 4071       1  "At this point, Mr. Brando announced: 'Somebod...
# 4072       0  Martin, 58, will be freed today after serving ...
# 4073       1  "We have concluded that the outlook for price ...
# 4074       1  The notification was first reported Friday by ...
# 4075       0  The 30-year bond US30YT=RR rose 22/32 for a yi...
#
#                                                String-2
# 0     Referring to him as only "the witness", Amrozi...
# 1     Yucaipa bought Dominick's in 1995 for $693 mil...
# 2     On June 10, the ship's owners had published an...
# 3     Tab shares jumped 20 cents, or 4.6%, to set a ...
# 4     PG&E Corp. shares jumped $1.63 or 8 percent to...
# ...                                                 ...
# 4071  Brando said that "somebody ought to put a bull...
# 4072  Martin served two thirds of a five-year senten...
# 4073  In a statement, the ECB said the outlook for p...
# 4074  MSNBC.com first reported the CIA request on Fr...
# 4075  The 30-year bond US30YT=RR grew 1-3/32 for a y...
#
# [4076 rows x 3 columns]

# %%
df = pd.read_csv(os.path.join(data_dir,'train_data.csv'))

# %%
# df.to_csv('train_data.csv')

# %%
df['Quality'] = df['Quality'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4076 entries, 0 to 4075
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4076 non-null   int64
#  1   Quality     4076 non-null   int32
#  2   String-1    4076 non-null   object
#  3   String-2    4076 non-null   object
# dtypes: int32(1), int64(1), object(2)
# memory usage: 111.6+ KB

# %%
# df.to_csv('dataframe.csv')

# %%
stop_words = set(stopwords.words('english'))

# %%
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

# %% [markdown]
# #### ANALYSING FOR BOTH THE LABELS

# %%
df_true = df[df["Quality"]==1]

# %%
df_false = df[df['Quality']==0]

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
def preprocess(text):
    text = text.lower() # comvert to lower case
    text = re.sub(r'[\d]','',text)
    text = contractions.fix(text) #fixing contractions
    text = re.sub(r'[^\w\s]','',text) #removing punctuations -> removing any character that is not a word or whitespace
    text = word_tokenize(text) #tokenizing
    text = [i for i in text if i not in stop_words] #removing stop words
    text = [i for i in text if not i.isdigit()] # removing numbers
    #text = [stemmer.stem(i) for i in text] # stemming
    text = [lemmatizer.lemmatize(i) for i in text] # lemmatizing
    return ' '.join(text)

# %%
df_true['String_1_preprocessed'] = tqdm(df_true['String-1'].apply(preprocess))
# Out:
# 100%|██████████| 2753/2753 [00:00<00:00, 2473633.01it/s]

# %%
df_true['String_2_preprocessed'] = tqdm(df_true['String-2'].apply(preprocess))
# Out:
# 100%|██████████| 2753/2753 [00:00<00:00, 2953176.19it/s]

# %%
df_true.columns
# Out:
# Index(['Unnamed: 0', 'Quality', 'String-1', 'String-2',
#        'String_1_preprocessed', 'String_2_preprocessed'],
#       dtype='object')

# %%
df_true = df_true.loc[:,['Quality','String_1_preprocessed','String_2_preprocessed']]
df_true
# Out:
#       Quality                              String_1_preprocessed  \
# 0           1  amrozi accused brother called witness delibera...
# 2           1  published advertisement internet june offering...
# 4           1  stock rose percent close friday new york stock...
# 5           1  revenue first quarter year dropped percent per...
# 7           1                dvdcca appealed state supreme court
# ...       ...                                                ...
# 4069        1  knox county health department following nation...
# 4070        1  new rule allow single company tv station reach...
# 4071        1  point mr brando announced somebody ought put b...
# 4073        1  concluded outlook price stability medium term ...
# 4074        1           notification first reported friday msnbc
#
#                                   String_2_preprocessed
# 0     referring witness amrozi accused brother delib...
# 2     june ship owner published advertisement intern...
# 4     pge corp share jumped percent new york stock e...
# 5     scandal hanging stewart company revenue first ...
# 7          dvd cca appealed decision yous supreme court
# ...                                                 ...
# 4069  health department spokesperson added departmen...
# 4070  changed national ownership limit allows compan...
# 4071  brando said somebody ought put bullet head acc...
# 4073  statement ecb said outlook price stability med...
# 4074         msnbccom first reported cia request friday
#
# [2753 rows x 3 columns]

# %%
df_true = df_true.iloc[:1500,:]
df_true.to_csv(path_or_buf=os.path.join(data_dir,'df_true_preprocessed_1.csv'))

# %%
df_false['String_1_preprocessed'] = tqdm(df_false['String-1'].apply(preprocess))
# Out:
# 100%|██████████| 1323/1323 [00:00<?, ?it/s]

# %%
df_false['String_2_preprocessed'] = tqdm(df_false['String-2'].apply(preprocess))
# Out:
# 100%|██████████| 1323/1323 [00:00<?, ?it/s]

# %%
df_false = df_false.loc[:,['Quality','String_1_preprocessed','String_2_preprocessed']]
df_false
# Out:
#       Quality                              String_1_preprocessed  \
# 1           0  yucaipa owned dominick selling chain safeway b...
# 3           0  around gmt tab share cent earlier set record high
# 6           0          nasdaq weekly gain percent closing friday
# 8           0     compared million cent per share yearago period
# 10          0  share genentech much larger company several pr...
# ...       ...                                                ...
# 4058        0  mr mcdevitt granted control three crucial aspe...
# 4059        0  linksys overtook cisco system leading wireless...
# 4060        0  rt jones analyst juli niemann said grant one p...
# 4072        0  martin freed today serving two third fiveyear ...
# 4075        0  year bond usytrr rose yield percent versus per...
#
#                                   String_2_preprocessed
# 1     yucaipa bought dominick million sold safeway b...
# 3         tab share jumped cent set record closing high
# 6     techlaced nasdaq composite ixic rallied point ...
# 8     earnings affected nonrecurring million tax ben...
# 10    share xoma fell percent early trade share gene...
# ...                                                 ...
# 4058  mr mcdevitt granted control three aspect polic...
# 4059  rolfe said linksys overtook cisco system last ...
# 4060  good reputation rt jones analyst juli niemann ...
# 4072  martin served two third fiveyear sentence mans...
# 4075  year bond usytrr grew yield percent percent la...
#
# [1323 rows x 3 columns]

# %%
df_final = pd.concat([df_true,df_false],axis=0)
df_final = df_final.reset_index()
df_final.to_csv(os.path.join(data_dir,'df_final.csv'))

# %%
df_final = pd.read_csv(os.path.join(data_dir,'df_final.csv'),index_col=0).drop(columns=['index'],axis=1)
df_final.head(10)
# Out:
#    Quality                              String_1_preprocessed  \
# 0        1  amrozi accused brother called witness delibera...
# 1        1  published advertisement internet june offering...
# 2        1  stock rose percent close friday new york stock...
# 3        1  revenue first quarter year dropped percent per...
# 4        1                dvdcca appealed state supreme court
# 5        1  said foodservice pie business fit company long...
# 6        1  added group performance would improve second h...
# 7        1  told sun newspaper mr hussein daughter british...
# 8        1  sheena young child national infertility suppor...
# 9        1  new finder put user folder hard drive network ...
#
#                                String_2_preprocessed
# 0  referring witness amrozi accused brother delib...
# 1  june ship owner published advertisement intern...
# 2  pge corp share jumped percent new york stock e...
# 3  scandal hanging stewart company revenue first ...
# 4       dvd cca appealed decision yous supreme court
# 5  foodservice pie business fit longterm growth s...
# 6  de sole said result statement group performanc...
# 7  saddam daughter british school hospital mind d...
# 8  sheena young spokesman child national infertil...
# 9  panther redesigned finder navigation tool put ...

# %%
df_final.dropna(inplace=True)

# %%
len(df_final)
# Out:
# 2823

# %%
x = df_final.iloc[:,1:]
y = df_final.iloc[:,0]

# %%
x
# Out:
#                                   String_1_preprocessed  \
# 0     amrozi accused brother called witness delibera...
# 1     published advertisement internet june offering...
# 2     stock rose percent close friday new york stock...
# 3     revenue first quarter year dropped percent per...
# 4                   dvdcca appealed state supreme court
# ...                                                 ...
# 2818  mr mcdevitt granted control three crucial aspe...
# 2819  linksys overtook cisco system leading wireless...
# 2820  rt jones analyst juli niemann said grant one p...
# 2821  martin freed today serving two third fiveyear ...
# 2822  year bond usytrr rose yield percent versus per...
#
#                                   String_2_preprocessed
# 0     referring witness amrozi accused brother delib...
# 1     june ship owner published advertisement intern...
# 2     pge corp share jumped percent new york stock e...
# 3     scandal hanging stewart company revenue first ...
# 4          dvd cca appealed decision yous supreme court
# ...                                                 ...
# 2818  mr mcdevitt granted control three aspect polic...
# 2819  rolfe said linksys overtook cisco system last ...
# 2820  good reputation rt jones analyst juli niemann ...
# 2821  martin served two third fiveyear sentence mans...
# 2822  year bond usytrr grew yield percent percent la...
#
# [2823 rows x 2 columns]

# %%
x_train = [(df_final['String_1_preprocessed'][i]+ "<EOS>" + df_final['String_2_preprocessed'][i]) for i in range(len(df_final))]

# %%
x_train[:5]
# Out:
# ['amrozi accused brother called witness deliberately distorting evidence<EOS>referring witness amrozi accused brother deliberately distorting evidence',
#  'published advertisement internet june offering cargo sale added<EOS>june ship owner published advertisement internet offering explosive sale',
#  'stock rose percent close friday new york stock exchange<EOS>pge corp share jumped percent new york stock exchange friday',
#  'revenue first quarter year dropped percent period year earlier<EOS>scandal hanging stewart company revenue first quarter year dropped percent period year earlier',
#  'dvdcca appealed state supreme court<EOS>dvd cca appealed decision yous supreme court']

# %% [markdown]
# ### USING BOW

# %%
vectorizer = CountVectorizer()
vectorizer.fit(x['String_1_preprocessed'],x['String_2_preprocessed'])
# Out:
# CountVectorizer()

# %%
X_train1 = vectorizer.transform(x['String_1_preprocessed'])
X_train2 = vectorizer.transform(x['String_2_preprocessed'])

# %%
def cosine(data1,data2):
    score = cosine_similarity(data1,data2)[0][0]
    return 1 if score>0.60 else 0

# %%
df_final_test.head()
x_test = df_final_test.iloc[:,1:]
y_test = df_final_test.iloc[:,0]

# %%
X_test1 = vectorizer.transform(x_test['String_1_preprocessed'])
X_test2 = vectorizer.transform(x_test['String_2_preprocessed'])

# %%
y_pred = []
for i in range(X_test1.shape[0]):
    y_pred+=[cosine(X_test1[i],X_test2[i])]

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.54      0.53       557
#            1       0.78      0.76      0.77      1168
#
#     accuracy                           0.69      1725
#    macro avg       0.65      0.65      0.65      1725
# weighted avg       0.69      0.69      0.69      1725

# %% [markdown]
# ### USING TF-IDF

# %%
tfidf_vectorizer = TfidfVectorizer()

# %%
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)

# %%
svc = SVC(C=1000,kernel='rbf')

# %%
svc.fit(x_train_tfidf,y)
# Out:
# SVC(C=1000)

# %%
tfidf_vectorizer.get_feature_names_out()
# Out:
# array(['_enough', 'aan', 'aaron', ..., 'zulfiqar', 'zulifquar', 'µguru'],
#       dtype=object)

# %% [markdown]
# TEST-DATA

# %%
quality = []
ID_1 = []
ID_2 = []
STRING_1 = []
STRING_2 = []

text_lines = []

# %%
fe = open(os.path.join(data_dir,'msr_paraphrase_test.txt'),'r',encoding='utf8')
columns = fe.readline().removeprefix('\ufeff').removesuffix('\n').split('\t')
# print(columns)
for line in fe:
    text_lines.append(line.strip().split('/n'))

# %%
for lines in text_lines:
    line = str(lines[0])
    split_lines = line.split('\t')
    quality.append(split_lines[0])
    STRING_1.append(split_lines[3])
    STRING_2.append(split_lines[4])

fe.close()

# %%
df_test = pd.DataFrame(np.column_stack([quality,STRING_1,STRING_2]),columns=['Quality','String-1','String-2'])

# %%
df_test['Quality'] = df_test['Quality'].astype('int')

# %%
df_test.to_csv(os.path.join(data_dir,'test_data.csv'))

# %%
df_test_true = df_test[df_test["Quality"]==1]

# %%
df_test_false = df_test[df_test["Quality"]==0]

# %%
df_test_true['String_1_preprocessed'] = tqdm(df_test_true['String-1'].apply(preprocess))
# Out:
# 100%|██████████| 1147/1147 [00:00<?, ?it/s]

# %%
df_test_true['String_2_preprocessed'] = tqdm(df_test_true['String-2'].apply(preprocess))
# Out:
# 100%|██████████| 1147/1147 [00:00<00:00, 1155624.96it/s]

# %%
df_test_true.columns
# Out:
# Index(['Quality', 'String-1', 'String-2', 'String_1_preprocessed',
#        'String_2_preprocessed'],
#       dtype='object')

# %%
df_test_true = df_test_true.loc[:,['Quality','String_1_preprocessed','String_2_preprocessed']]
df_test_true
# Out:
#       Quality                              String_1_preprocessed  \
# 0           1  pccws chief operating officer mike butcher ale...
# 1           1  world two largest automaker said yous sale dec...
# 2           1  according federal center disease control preve...
# 5           1  settling company would also assign possible cl...
# 7           1  washington county man may county first human c...
# ...       ...                                                ...
# 1716        1  gehring waived extradition monday hearing san ...
# 1717        1  advised certain allegation criminal conduct in...
# 1719        1  deal approved company board director expected ...
# 1723        1  last week power station u owner aes corp walke...
# 1724        1  sobigf spread unsuspecting computer user open ...
#
#                                   String_2_preprocessed
# 0     current chief operating officer mike butcher g...
# 1     domestic sale gm ford motor co declined predic...
# 2     center disease control prevention said reporte...
# 5     agreement settling company also assign potenti...
# 7     county first human case west nile year confirm...
# ...                                                 ...
# 1716  gehring waived extradition monday hearing sant...
# 1717  advised certain allegation criminal conduct in...
# 1719  acquisition approved company board director ex...
# 1723  news come draxs american owner aes corp aesn l...
# 1724  virus spread unsuspecting computer user open f...
#
# [1147 rows x 3 columns]

# %%
df_test_true.to_csv(os.path.join(data_dir,'df_test_true_preprocessed_1.csv'))

# %%
df_test_false['String_1_preprocessed'] = tqdm(df_test_false['String-1'].apply(preprocess))
# Out:
# 100%|██████████| 578/578 [00:00<00:00, 287717.51it/s]

# %%
df_test_false['String_2_preprocessed'] = tqdm(df_test_false['String-2'].apply(preprocess))
# Out:
# 100%|██████████| 578/578 [00:00<00:00, 577628.71it/s]

# %%
df_test_false = df_test_false.loc[:,['Quality','String_1_preprocessed','String_2_preprocessed']]
df_test_false
# Out:
#       Quality                              String_1_preprocessed  \
# 3           0  tropical storm rapidly developed gulf mexico s...
# 4           0             company detail cost replacement repair
# 6           0  air commodore quaife said hornet remained thre...
# 9           0  broader standard poor index spx point lower pe...
# 13          0  hong kong flat australia singapore south korea...
# ...       ...                                                ...
# 1713        0  planned stay day river crested forecast late l...
# 1718        0  crew worked install new culvert prepare highwa...
# 1720        0  hughes refused rehire hernandez complained equ...
# 1721        0                       democrat assembly republican
# 1722        0  bethany hamilton remained stable condition sat...
#
#                                   String_2_preprocessed
# 3     tropical storm rapidly developed gulf mexico s...
# 4     company official expect cost replacement work ...
# 6     air commodore john quaife said security operat...
# 9     technologylaced nasdaq composite index ixic po...
# 13    australia flat singapore percent midday south ...
# ...                                                 ...
# 1713           lawyer planned stay river start receding
# 1718  crew worked install new culvert repave highway...
# 1720  hernandez filed equal employment opportunity c...
# 1721  democrat dominate assembly republican control ...
# 1722  bethany remained stable condition attack frida...
#
# [578 rows x 3 columns]

# %%
df_final_test = pd.concat([df_test_true,df_test_false],axis=0)
df_final_test = df_final_test.reset_index().drop(columns=['index'],axis=1)
df_final_test.to_csv(os.path.join(data_dir,'df_final_test.csv'))

# %%
df_final_test = pd.read_csv(os.path.join(data_dir,'df_final_test.csv'),index_col=0)

# %%
df_final_test.head()
# Out:
#    Quality                              String_1_preprocessed  \
# 0        1  pccws chief operating officer mike butcher ale...
# 1        1  world two largest automaker said yous sale dec...
# 2        1  according federal center disease control preve...
# 3        1  settling company would also assign possible cl...
# 4        1  washington county man may county first human c...
#
#                                String_2_preprocessed
# 0  current chief operating officer mike butcher g...
# 1  domestic sale gm ford motor co declined predic...
# 2  center disease control prevention said reporte...
# 3  agreement settling company also assign potenti...
# 4  county first human case west nile year confirm...

# %%
len(df_final_test)
# Out:
# 1725

# %%
x_test = df_final_test.iloc[:,1:]
y_test = df_final_test.iloc[:,0]

# %%
x_test = [(df_final_test['String_1_preprocessed'][i]+ "<EOS>" + df_final_test['String_2_preprocessed'][i]) for i in range(len(df_final_test))]
x_test_tfidf = tfidf_vectorizer.transform(x_test)
y_pred = svc.predict(x_test_tfidf)

# %%
print(classification_report(y_pred=y_pred,y_true=y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.51      0.49       578
#            1       0.74      0.72      0.73      1147
#
#     accuracy                           0.65      1725
#    macro avg       0.61      0.61      0.61      1725
# weighted avg       0.65      0.65      0.65      1725

# %% [markdown]
# #### USING FastText

# %%
df_final['String_1_preprocessed_split'] = df_final['String_1_preprocessed'].apply(lambda x : x.split())
df_final['String_2_preprocessed_split'] = df_final['String_2_preprocessed'].apply(lambda x : x.split())

df_final_test['String_1_preprocessed_split'] = df_final_test['String_1_preprocessed'].apply(lambda x : x.split())
df_final_test['String_2_preprocessed_split'] = df_final_test['String_2_preprocessed'].apply(lambda x : x.split())

# %%
sentences_train = df_final['String_1_preprocessed_split'].tolist() + df_final['String_2_preprocessed_split'].tolist()
sentences_test = df_final_test['String_1_preprocessed_split'].tolist() + df_final_test['String_2_preprocessed_split'].tolist()

# %%
ft_model = FastText(sentences=sentences_train,vector_size=100,epochs=50,window=3,workers=4,sg=1,min_count=3)

# %%
def get_word_vector_ft(word):
    if word in ft_model.wv:
        return ft_model.wv[word]
    else:
        return np.zeros(100)
def get_sent_vect_ft(sent,maxlen=10):
    sent_len = len(sent)
    sent_vect = []
    if sent_len<maxlen:
        for word in sent:
            sent_vect.append(get_word_vector_ft(word))
        for i in range(maxlen-len(sent_vect)):
            sent_vect.append(np.zeros(100))
    else:
        for i in range(maxlen):
            sent_vect.append(get_word_vector_ft(sent[i]))
    return np.asarray(sent_vect)

# %%
df_final['str_1_vector'] = df_final['String_1_preprocessed'].apply(lambda x : get_sent_vect_ft(x))
df_final['str_2_vector'] = df_final['String_2_preprocessed'].apply(lambda x : get_sent_vect_ft(x))

df_final_test['str_1_vector'] = df_final_test['String_1_preprocessed'].apply(lambda x : get_sent_vect_ft(x))
df_final_test['str_2_vector'] = df_final_test['String_2_preprocessed'].apply(lambda x : get_sent_vect_ft(x))

# %%
y_pred=[]
sim_scores = []
for i in range(len(df_final_test)):
    sent_1 = df_final_test['str_1_vector'][i]
    sent_2 = df_final_test['str_2_vector'][i]
    sim_score = cosine_similarity(sent_1,sent_2)[0][0]
    sim_scores.append(sim_score)
    if sim_score>0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

print(classification_report(y_pred=y_pred,y_true=y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.32      0.36       578
#            1       0.69      0.76      0.72      1147
#
#     accuracy                           0.61      1725
#    macro avg       0.55      0.54      0.54      1725
# weighted avg       0.59      0.61      0.60      1725

# %% [markdown]
# ### USING SIMILARITY SCORE

# %% [markdown]
# #### SENTENCE EMBEDDING -> DOC2VEC

# %%
def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

# %%
x
# Out:
#                                   String_1_preprocessed  \
# 0     amrozi accused brother called witness delibera...
# 1     published advertisement internet june offering...
# 2     stock rose percent close friday new york stock...
# 3     revenue first quarter year dropped percent per...
# 4                   dvdcca appealed state supreme court
# ...                                                 ...
# 2818  mr mcdevitt granted control three crucial aspe...
# 2819  linksys overtook cisco system leading wireless...
# 2820  rt jones analyst juli niemann said grant one p...
# 2821  martin freed today serving two third fiveyear ...
# 2822  year bond usytrr rose yield percent versus per...
#
#                                   String_2_preprocessed
# 0     referring witness amrozi accused brother delib...
# 1     june ship owner published advertisement intern...
# 2     pge corp share jumped percent new york stock e...
# 3     scandal hanging stewart company revenue first ...
# 4          dvd cca appealed decision yous supreme court
# ...                                                 ...
# 2818  mr mcdevitt granted control three aspect polic...
# 2819  rolfe said linksys overtook cisco system last ...
# 2820  good reputation rt jones analyst juli niemann ...
# 2821  martin served two third fiveyear sentence mans...
# 2822  year bond usytrr grew yield percent percent la...
#
# [2823 rows x 2 columns]

# %%
x['String_1_split'] = x['String_1_preprocessed'].apply(lambda x : word_tokenize(x))
x['String_2_split'] = x['String_2_preprocessed'].apply(lambda x : word_tokenize(x))

# %%
tokenized_sent = x['String_1_split'].tolist() + x['String_2_split'].tolist()

# %%
tagged_data = [TaggedDocument(d, [i]) for i, d in enumerate(tokenized_sent)]
tagged_data[:5]
# Out:
# [TaggedDocument(words=['amrozi', 'accused', 'brother', 'called', 'witness', 'deliberately', 'distorting', 'evidence'], tags=[0]),
#  TaggedDocument(words=['published', 'advertisement', 'internet', 'june', 'offering', 'cargo', 'sale', 'added'], tags=[1]),
#  TaggedDocument(words=['stock', 'rose', 'percent', 'close', 'friday', 'new', 'york', 'stock', 'exchange'], tags=[2]),
#  TaggedDocument(words=['revenue', 'first', 'quarter', 'year', 'dropped', 'percent', 'period', 'year', 'earlier'], tags=[3]),
#  TaggedDocument(words=['dvdcca', 'appealed', 'state', 'supreme', 'court'], tags=[4])]

# %%
model = Doc2Vec(tagged_data, vector_size = 20, window = 2, min_count = 1, epochs = 100)

# %%
# model.wv

# %%
# test_doc = word_tokenize("I had pizza and pasta".lower())
# test_doc_vector = model.infer_vector(test_doc)
# model.docvecs.most_similar(positive = [test_doc_vector])

def get_sent_vector(sent):
    sent = word_tokenize(sent)
    sent_vector = model.infer_vector(sent)
    return sent_vector

def get_sim_score(sent1,sent2):
    return cosine(get_sent_vector(sent1),get_sent_vector(sent2))

# %%
df_final_test.head()
# Out:
#    Quality                              String_1_preprocessed  \
# 0        1  pccws chief operating officer mike butcher ale...
# 1        1  world two largest automaker said yous sale dec...
# 2        1  according federal center disease control preve...
# 3        1  settling company would also assign possible cl...
# 4        1  washington county man may county first human c...
#
#                                String_2_preprocessed
# 0  current chief operating officer mike butcher g...
# 1  domestic sale gm ford motor co declined predic...
# 2  center disease control prevention said reporte...
# 3  agreement settling company also assign potenti...
# 4  county first human case west nile year confirm...

# %%
y_pred=[]
sim_scores = []
for i in range(len(df_final_test)):
    sent_1 = df_final_test['String_1_preprocessed'][i]
    sent_2 = df_final_test['String_2_preprocessed'][i]
    sim_score = get_sim_score(sent_1,sent_2)
    sim_scores.append(sim_score)
    if sim_score>0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

print(classification_report(y_pred=y_pred,y_true=y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.42      0.46       578
#            1       0.73      0.79      0.76      1147
#
#     accuracy                           0.67      1725
#    macro avg       0.62      0.61      0.61      1725
# weighted avg       0.65      0.67      0.66      1725

# %% [markdown]
# ### SENTENCE EMBEDDING ->SENTENCE BERT

# %%
sbert_model = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
sentences = x['String_1_preprocessed'].tolist() + x['String_2_preprocessed'].tolist()

# %%
sentence_embeddings = sbert_model.encode(sentences)

# %%
print(sentences[0])
print('Sample BERT embedding vector - length', len(sentence_embeddings[0]))
print('Sample BERT embedding vector - note includes negative values', sentence_embeddings[0])
# Out:
# amrozi accused brother called witness deliberately distorting evidence
# Sample BERT embedding vector - length 768
# Sample BERT embedding vector - note includes negative values [-4.84880293e-03  6.70211792e-01  9.93917346e-01  4.23760623e-01
#   3.49516392e-01  1.50311485e-01  7.54621506e-01 -2.76908726e-01
#   4.35927570e-01  1.13792725e-01 -2.95178175e-01  5.54410756e-01
#   7.54509494e-02  9.08544123e-01 -1.15884709e+00  7.80411810e-02
#   7.81229064e-02 -9.46962535e-01  1.07690468e-01 -3.94617260e-01
#  -1.15400357e-02  5.23896003e-03  9.71267596e-02  2.73131490e-01
#   2.96102345e-01  6.90533161e-01 -4.71219361e-01 -9.52201664e-01
#  -1.55344808e+00  3.86499017e-01  9.34361741e-02  6.51992917e-01
#   2.73635029e-03 -1.51803970e-01 -7.50415742e-01  6.34284496e-01
#   9.08018231e-01 -5.41589677e-01 -4.60812189e-02  5.35555780e-01
#   5.72790980e-01  6.91431701e-01 -3.84634763e-01  1.51890725e-01
#  -5.02098083e-01 -1.57897115e-01  4.89452899e-01  9.82423246e-01
#   9.17938113e-01 -6.99086368e-01  2.57459700e-01  2.72043590e-02
#   1.53357580e-01  4.86850590e-01 -3.18577498e-01  1.89183667e-01
#   3.03911865e-01 -1.41963315e+00  1.73586220e-01 -1.72453329e-01
#  -1.09031177e+00  1.47825450e-01  1.22484124e+00  8.61048162e-01
#  -4.91461903e-01  9.15373921e-01  2.80949533e-01  7.56483018e-01
#  -9.57582593e-01 -7.45322645e-01  7.56371021e-02 -6.81297898e-01
#  -9.78178561e-01 -1.68459147e-01  4.26575959e-01 -3.15593928e-01
#  -2.92765617e-01  4.82652605e-01  5.05977094e-01  3.70413989e-01
#  -8.35409820e-01  1.16485707e-01 -2.50257254e-01 -5.95166385e-01
#   6.31753325e-01  6.68228269e-01  1.00325501e+00  6.52208775e-02
#  -7.25263894e-01 -1.39018625e-01  5.94940186e-01  3.42026770e-01
#   9.38761115e-01 -7.15511382e-01 -9.42287266e-01 -9.00086403e-01
#   3.48414272e-01 -1.20295681e-01  3.78732651e-01  5.93261421e-01
#  -3.94074708e-01  7.95855150e-02  3.19393188e-01  4.55488265e-01
#  -1.61736280e-01 -3.68425287e-02  3.14484447e-01 -1.06881070e+00
#  -4.44590092e-01 -1.58558320e-02  1.63469210e-01  2.14354113e-01
#   1.68746099e-01 -1.39347464e-01 -7.65301764e-01 -2.76902437e-01
#  -9.72162127e-01  3.65126997e-01 -2.73872763e-01  5.69640696e-01
#   4.64806080e-01  4.40900654e-01  1.12732910e-01  2.44464040e-01
#   7.76858747e-01 -8.77168328e-02  1.26387560e+00  8.97311985e-01
#  -7.03247726e-01  2.01596633e-01  1.86623428e-02  7.69127250e-01
#   4.21757996e-01 -4.55213152e-02 -6.80930495e-01  2.26282910e-01
#   9.10454273e-01 -5.22649884e-01  9.18389708e-02 -2.84082144e-01
#  -4.75797690e-02 -4.98393953e-01  5.55926681e-01 -6.08828843e-01
#  -9.64803755e-01  2.09154367e-01  4.81451303e-01  9.60908607e-02
#   2.10124210e-01 -2.00518340e-01 -7.92717412e-02 -1.40554056e-01
#  -4.61196527e-02  6.05799973e-01  3.72479618e-01  1.96071953e-01
#   1.24526575e-01 -3.48313302e-01 -1.06107913e-01  2.18329176e-01
#  -2.71646027e-02  6.73238933e-02 -8.14657956e-02 -2.20654123e-02
#  -7.80256391e-02  5.87876663e-02 -6.94617480e-02 -3.09712857e-01
#  -1.43229350e-01 -1.46333724e-01 -3.37430507e-01  4.12776530e-01
#   1.77859080e+00 -9.61056530e-01  1.66009247e+00  6.63897038e-01
#  -4.81653750e-01 -6.90905154e-01  2.08062097e-01 -2.76832521e-01
#  -3.52167040e-01  2.98911065e-01 -1.38540816e+00  4.03893381e-01
#  -2.11561337e-01 -3.55069339e-01  8.09369236e-02 -5.61206162e-01
#   2.65892088e-01 -6.89677224e-02  1.05805553e-01 -1.07894302e-03
#   1.57776088e-01 -6.38776660e-01 -3.48480374e-01  4.73758399e-01
#   3.44910085e-01  2.64700919e-01 -2.02933356e-01  1.95160732e-01
#  -3.33646387e-01 -2.51332015e-01 -3.54572386e-01  3.47510099e-01
#  -6.82777703e-01  4.13470179e-01  8.03568512e-02  2.78877109e-01
#  -1.62775621e-01 -5.10116935e-01 -4.46929127e-01  2.89700955e-01
#  -5.35403132e-01  4.73129541e-01  1.40651584e-01 -6.32597730e-02
#   8.88386592e-02 -1.07654333e-01  1.06331992e+00  1.04519856e+00
#   1.71832398e-01 -1.86728314e-01 -1.83205977e-01  1.44495583e+00
#  -6.49532497e-01  1.58322656e+00 -2.86538396e-02 -7.26660863e-02
#  -1.29834354e+00  7.16022193e-01  1.28856704e-01 -1.09569736e-01
#   1.46077245e-01 -6.56084001e-01 -6.98421001e-01 -6.41625822e-01
#  -1.12390339e+00 -2.11813688e-01  1.02262330e+00 -4.95655984e-01
#   6.41683280e-01  6.46009147e-01  1.03494477e+00  1.06650507e+00
#  -2.16063425e-01 -3.12703311e-01  4.66381246e-03 -6.33764565e-01
#  -1.46794438e-01  6.13674641e-01 -1.45545924e+00 -3.67706686e-01
#   2.59292185e-01 -9.51500833e-01  1.57272726e-01 -2.19490975e-01
#   5.07707894e-01  9.25464034e-01 -1.00468799e-01 -7.11109862e-02
#   2.80991942e-02  3.72764260e-01 -1.37742805e+00  3.70018154e-01
#  -3.15508157e-01 -8.67260844e-02 -2.26311255e-02  8.02914619e-01
#  -7.38098800e-01  2.17062950e-01 -6.16283298e-01 -9.46695030e-01
#  -6.36208117e-01  8.46302450e-01 -4.42037880e-01  6.17840551e-02
#  -1.28681436e-01 -7.03994259e-02  5.77347159e-01 -1.51303217e-01
#  -2.91859657e-01  6.60908163e-01 -1.63430774e+00  4.35795516e-01
#  -7.18407273e-01  4.53068465e-01 -4.34356362e-01 -9.44995880e-03
#   4.52161312e-01 -5.26690423e-01 -4.18275774e-01  5.15336275e-01
#   1.67657331e-01 -3.18008736e-02  5.48705280e-01 -1.66499525e-01
#   4.04705048e-01 -1.00459051e+00  1.30295411e-01 -2.85052717e-01
#  -6.66674912e-01  2.61999518e-01 -8.68422806e-01  1.41574785e-01
#  -3.22964519e-01 -1.43947512e-01  2.80423701e-01  1.02816975e+00
#  -6.61903203e-01 -5.08700073e-01 -1.53521746e-01  2.42594332e-01
#   1.48049667e-01  3.96191984e-01  5.52304149e-01 -8.01268935e-01
#  -1.16466820e+00 -2.49505058e-01  5.06000817e-01 -5.56016147e-01
#   4.27818112e-02 -2.46141121e-01  4.42072421e-01 -3.49543035e-01
#   8.95879790e-02 -3.27614546e-01  4.40997273e-01  9.68174934e-02
#  -2.78464675e-01 -8.23112875e-02  2.98475653e-01 -8.89974177e-01
#   1.38266742e-01  5.18010437e-01  4.82756674e-01  3.64176840e-01
#  -1.13525689e+00  4.25366312e-01 -5.07861733e-01 -1.88594222e-01
#   1.90170801e+00  3.94881397e-01 -9.13324475e-01 -9.99120712e-01
#   5.08369923e-01 -1.94456249e-01 -4.24663603e-01  5.16624749e-02
#  -3.71929497e-01  2.13475063e-01  4.05606031e-01  5.75393736e-01
#   3.60901624e-01  2.45078593e-01 -1.05751979e+00 -1.11995018e+00
#  -7.35682428e-01  5.97256005e-01 -2.58614391e-01  4.43896428e-02
#  -4.01266277e-01  5.47818899e-01 -1.54294610e+00 -1.11619079e+00
#   6.63330182e-02 -3.81030887e-01 -1.93425745e-01  8.56634676e-01
#   3.53840321e-01  5.36899567e-01 -2.39574328e-01  9.90507662e-01
#  -1.63076799e-02 -7.37178326e-01 -1.73148558e-01 -1.24467003e+00
#   4.03603554e-01 -1.97178230e-01 -4.24420565e-01 -1.89794391e-01
#   1.85156867e-01 -4.70615238e-01  6.81116164e-01  4.99208778e-01
#  -4.62658219e-02 -7.01819062e-01  4.21243936e-01  5.91727138e-01
#   7.57449210e-01  8.30770507e-02  4.39526945e-01  1.28985777e-01
#  -1.54760256e-01 -1.09834291e-01 -1.74322277e-01 -5.04194021e-01
#   6.16547287e-01  3.24440926e-01  5.65344512e-01 -1.14058904e-01
#   2.38529101e-01  6.86306655e-01 -4.10957605e-01  6.94464266e-01
#   5.30262589e-01  9.18878257e-01  4.82839435e-01  5.65461278e-01
#  -8.82311761e-01 -7.18894362e-01  4.01124299e-01 -3.15936863e-01
#  -3.47011723e-02  4.77321856e-02  1.04354791e-01 -1.79876074e-01
#  -4.96367067e-01 -9.13814068e-01  3.57150398e-02  7.76573718e-01
#   1.48355052e-01  5.79078853e-01  2.74459869e-01 -1.30334544e+00
#   1.30202681e-01  3.57006639e-01 -3.30141097e-01  2.10705609e-03
#  -1.05956189e-01 -1.73926935e-01 -1.63429290e-01  3.87869985e-03
#  -8.94669950e-01 -3.26498508e-01  1.38102276e-02 -3.55587006e-01
#   9.97487426e-01  4.24214184e-01  8.58714104e-01 -6.58973813e-01
#   6.14707589e-01 -4.10057396e-01  9.57132697e-01  4.08732854e-02
#  -9.74452198e-01 -5.07106213e-03 -7.08949029e-01 -2.69434124e-01
#   8.43541920e-01 -2.40531877e-01  4.84209120e-01  8.83922577e-02
#   3.37265700e-01  2.58140653e-01  7.65884578e-01 -4.32642281e-01
#  -1.85264587e-01 -2.04893827e-01 -4.40710932e-01 -7.54562795e-01
#   8.58490765e-01  7.34316170e-01 -2.16339707e-01 -2.18046799e-01
#   1.80606451e-02  9.97344255e-02 -4.69093144e-01 -5.02784431e-01
#   2.40203872e-01  3.17069203e-01 -4.95485365e-01  3.70323332e-03
#   2.39655346e-01  6.90707207e-01 -3.09398264e-01 -1.58197141e+00
#  -7.21732557e-01  6.80632532e-01 -5.62539279e-01  2.66265851e-02
#   1.94874555e-01 -8.67583137e-03  7.58266270e-01  5.08618474e-01
#  -7.15214759e-02 -4.80832785e-01  4.66358811e-01 -1.67966820e-02
#   2.45733425e-01  1.53173879e-01 -7.66609967e-01  4.68836486e-01
#  -2.70763546e-01 -1.13588977e+00 -2.49782667e-01 -1.98049390e+00
#  -5.92844963e-01  3.06759417e-01  1.71452388e-01  2.63354927e-01
#   7.11538494e-01  8.46992195e-01  6.05864227e-01 -3.03331316e-01
#   3.33356202e-01  3.29194307e-01  7.86238670e-01  3.19260806e-01
#   3.89761448e-01  7.85714686e-01  1.97905526e-01 -9.62318778e-02
#  -1.47505715e-01 -9.17478919e-01 -8.44534263e-02  8.13046515e-01
#  -1.91030219e-01  1.68606520e-01  2.65970767e-01 -3.94034863e-01
#  -1.18251288e+00  5.50873280e-01  1.30133712e+00 -9.80217516e-01
#   1.38622224e+00 -3.36106747e-01 -6.55743182e-01  9.86689687e-01
#   1.60487697e-01 -1.90475106e-01 -4.25619423e-01  1.65582076e-01
#  -2.16100723e-01 -3.09628218e-01 -2.36200228e-01 -1.85174718e-01
#  -1.01415381e-01  2.79046595e-01  5.58313727e-01  5.82006983e-02
#   8.00665975e-01  4.41888481e-01  8.50302875e-01  5.85574098e-02
#  -9.92785573e-01  7.49609530e-01  1.86796859e-01 -4.85313267e-01
#  -5.97466290e-01 -3.76401246e-01 -3.48023146e-01  3.25710773e-01
#   7.03951478e-01 -2.85374194e-01  2.04004019e-01  2.93529481e-02
#   2.95183863e-02  7.45237887e-01 -2.33344316e-01  9.92077291e-01
#   4.55133580e-02  2.63146281e-01 -1.69373363e-01  2.62450904e-01
#  -7.86942914e-02 -1.32775319e+00  8.50025490e-02 -2.43193656e-01
#  -8.61326754e-01 -6.90812320e-02  8.03785741e-01 -4.46775645e-01
#   8.85241568e-01  2.80541331e-01  4.52140540e-01  3.52058202e-01
#  -3.64501894e-01 -7.51057625e-01 -9.38578308e-01  5.95216863e-02
#   7.66046420e-02  4.85956132e-01 -5.44786513e-01  1.55387208e-01
#  -2.55509287e-01 -3.75313133e-01  3.86112154e-01 -1.80942744e-01
#  -4.55176681e-01 -6.39608741e-01  2.66439408e-01 -3.66901964e-01
#   4.09226306e-02  4.11276877e-01  5.37457168e-01 -5.28763115e-01
#   7.85148218e-02 -1.47575989e-01 -3.31820399e-01 -4.08809394e-01
#   3.90867144e-01 -3.17225559e-03 -8.01252425e-01 -1.16493795e-02
#  -6.62768185e-01  5.19780040e-01  1.42268687e-01  3.74609530e-01
#   7.31009468e-02 -3.49256128e-01  4.51109171e-01 -9.01264846e-01
#   3.87332171e-01  3.04973871e-01 -6.31036460e-01 -9.86122429e-01
#  -7.56933570e-01 -2.58279473e-01  1.13975905e-01 -4.67494309e-01
#   4.08657104e-01 -1.09699571e+00  1.39431462e-01 -4.34539348e-01
#   1.05301440e+00 -7.54319787e-01  3.36221069e-01 -5.41538417e-01
#   3.78251076e-01  6.92148030e-01  6.26085103e-01  1.69196770e-01
#   6.11715853e-01  2.00886652e-01  8.41454864e-02  6.61119103e-01
#  -5.83778247e-02 -1.90293878e-01  9.10209566e-02  2.39697974e-02
#  -1.01604068e+00  9.60699499e-01  2.90802252e-02 -4.70677048e-01
#   4.50116456e-01 -7.80674815e-01 -7.71842822e-02 -8.66873481e-04
#   2.78799981e-01  2.72274792e-01  2.42468804e-01  3.63008708e-01
#  -1.63884401e-01  9.11865234e-02  1.35289639e-01 -6.02484345e-02
#  -3.68269891e-01  4.86159146e-01 -4.78753567e-01  2.45843604e-01
#   4.71938819e-01 -4.57730144e-01  3.76383364e-01  8.60868674e-03
#   3.33417207e-01  1.11319220e+00 -3.42060745e-01 -1.97221249e-01
#   3.70561657e-03  4.26960528e-01 -9.66310874e-02 -3.56924646e-02
#   9.59080040e-01 -9.11202252e-01  3.58266860e-01 -7.38876760e-01
#   3.60054493e-01 -2.60683388e-01 -3.44666183e-01 -1.21774638e+00
#   2.32988700e-01 -1.53681564e+00 -2.59091049e-01 -1.01135230e+00
#   1.03100801e+00 -4.78668451e-01 -5.42310774e-01  2.45836139e-01
#  -3.02459538e-01  5.31068258e-02 -5.70772700e-02 -9.41134244e-03
#  -1.03201365e+00 -6.52999461e-01  1.40465394e-01  1.82423159e-01
#  -1.20669973e+00 -3.03694736e-02 -5.81213653e-01 -7.19570279e-01
#  -7.81426728e-01  6.84020042e-01 -5.19613743e-01  2.98909992e-01
#  -7.24893436e-02 -4.69532639e-01 -4.47567046e-01  5.20781398e-01
#   1.93997957e-02  5.53413156e-05 -6.13513768e-01  4.36764926e-01
#  -6.13810241e-01 -6.38549268e-01 -1.11789787e+00  5.12240946e-01
#  -4.79969025e-01 -2.02182159e-01 -4.15313244e-01 -4.77801353e-01
#  -5.73024690e-01 -3.78694922e-01 -5.03016651e-01 -5.29663384e-01
#   5.84642947e-01 -4.01478022e-01  2.55258501e-01  3.08196366e-01
#  -7.14003980e-01  1.32418409e-01  8.21191907e-01 -3.96287143e-01
#   2.17552453e-01 -1.90913573e-01  1.32760990e+00  7.45375752e-01
#   3.98122609e-01 -2.17952818e-01 -5.74614048e-01 -1.85147476e+00
#  -8.52446631e-02  5.56892566e-02  5.04165404e-02 -1.61808670e+00
#   7.46978596e-02 -8.28403383e-02 -1.89249247e-01 -1.18423857e-01
#   3.77101690e-01  9.86044295e-03  6.41285837e-01 -2.80836016e-01
#   3.89169037e-01  9.62797999e-01 -4.42605764e-01 -8.99258628e-02
#   6.37058243e-02 -1.21553883e-01  2.92553246e-01 -9.02338624e-02
#  -8.01395833e-01 -2.15034986e+00 -8.01076964e-02  4.95658331e-02
#   1.51526093e-01 -1.11603260e-01 -1.18190885e-01  1.08652309e-01]

# %%
def get_bert_vector(sent):
    vector = sbert_model.encode([sent])[0]
    return vector

# %%
def get_bert_sim_score(sent1,sent2):
    sent_1_vector = sbert_model.encode([sent1])[0]
    sent_2_vector = sbert_model.encode([sent2])[0]

    sim_score = cosine(sent_1_vector,sent_2_vector)
    return sim_score

# %%
y_pred = []
bert_sim_scores = []
for i in range(len(df_final_test)):
    sent_1 = df_final_test['String_1_preprocessed'][i]
    sent_2 = df_final_test['String_2_preprocessed'][i]
    sim_score = get_bert_sim_score(sent_1,sent_2)
    bert_sim_scores.append(sim_score)
    if sim_score>0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
print(classification_report(y_pred=y_pred,y_true=y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.03      0.06       578
#            1       0.67      0.99      0.80      1147
#
#     accuracy                           0.67      1725
#    macro avg       0.70      0.51      0.43      1725
# weighted avg       0.69      0.67      0.55      1725
